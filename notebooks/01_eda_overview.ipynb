# %%
# NYC Airbnb Market Analysis – EDA

This notebook performs exploratory data analysis on NYC Airbnb listings to understand pricing drivers, demand patterns, and market behavior.
# Out:
#   File "/tmp/ipython-input-4004907800.py", line 3
#     This notebook performs exploratory data analysis on NYC Airbnb listings to understand pricing drivers, demand patterns, and market behavior.
#          ^
# SyntaxError: invalid syntax

# %%
## 1. Problem Statement

Airbnb hosts and investors need to understand what drives pricing and demand across NYC neighborhoods.
This analysis aims to uncover patterns that can guide pricing strategy and market positioning.

# %%
## 2. Dataset

Source: Kaggle – New York City Airbnb Open Data (AB_NYC_2019)

The dataset contains:
- Location
- Room type
- Price
- Availability
- Reviews

# %%
## 3. Objectives

- Understand price distribution
- Identify price drivers
- Compare boroughs and neighborhoods
- Generate business insights
# Out:
#   File "/tmp/ipython-input-3390661907.py", line 3
#     - Understand price distribution
#                  ^
# SyntaxError: invalid syntax

# %%
## 4. Setup

# %%
df = pd.read_csv("/content/sample_data/NYC_Airbnb_Dat.csv")
df.shape
# Out:
# (48895, 16)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 120)

# %%
df.head()
# Out:
#      id                                              name  host_id    host_name neighbourhood_group neighbourhood  \
# 0  2539                Clean & quiet apt home by the park     2787         John            Brooklyn    Kensington
# 1  2595                             Skylit Midtown Castle     2845     Jennifer           Manhattan       Midtown
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth           Manhattan        Harlem
# 3  3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne            Brooklyn  Clinton Hill
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura           Manhattan   East Harlem
#
#    latitude  longitude        room_type  price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  40.64749  -73.97237     Private room    149               1                  9  19-10-2018               0.21
# ...

# %%
## 6. Initial Data Inspection
df.info()
(df.isna().mean().sort_values(ascending=False) * 100).round(2).head(10)
df["price"].describe()
df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
(df.isna().mean().sort_values(ascending=False) * 100).round(2).head(10)
# Out:
# last_review            20.56
# reviews_per_month      20.56
# host_name               0.04
# name                    0.03
# neighbourhood_group     0.00
# neighbourhood           0.00
# id                      0.00
# host_id                 0.00
# longitude               0.00
# latitude                0.00
# dtype: float64

# %%
df["price"].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64
